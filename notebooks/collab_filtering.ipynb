# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
# from sklearn.metrics.pairwise import cosine_similarity

# %%
from scipy.sparse import coo_matrix

# %%
datasetA=pd.read_csv(r"D:\PRJ1\datasets\cleaneddatasets\Acleaned.csv")
datasetR=pd.read_csv(r"D:\PRJ1\datasets\cleaneddatasets\Rcleaned.csv")

# %%
newR=pd.read_csv(r"D:\PRJ1\datasets\cleaneddatasets\reduced datasets\newR.csv")

# %%
dataset_AR=datasetR.merge(datasetA[["anime_id","name"]],on="anime_id")
dataset_AR
# Out:
#          user_id  anime_id  rating  \
# 0              3        20       8
# 1              3       154       6
# 2              3       170       9
# 3              3       199      10
# 4              3       225       9
# ...          ...       ...     ...
# 5695961    73515     13659       8
# 5695962    73515     14345       7
# 5695963    73515     16512       7
# 5695964    73515     17187       9
# 5695965    73515     22145      10
#
#                                                     name
# 0                                                 Naruto
# 1                                            Shaman King
# 2                                              Slam Dunk
# 3                          Sen to Chihiro no Kamikakushi
# 4                                         Dragon Ball GT
# ...                                                  ...
# 5695961     Ore no Imouto ga Konnani Kawaii Wake ga Nai.
# 5695962                                          Btooom!
# 5695963                   Devil Survivor 2 The Animation
# 5695964  Ghost in the Shell: Arise - Border:1 Ghost Pain
# 5695965                     Kuroshitsuji: Book of Circus
#
# [5695966 rows x 4 columns]

# %%
# dataset=datasetA.merge(datasetR[["anime_id","user_id"]],on="anime_id")
# dataset
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 1           32281                                     Kimi no Na wa.
# 2           32281                                     Kimi no Na wa.
# 3           32281                                     Kimi no Na wa.
# 4           32281                                     Kimi no Na wa.
# ...           ...                                                ...
# 5695961      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 5695962      5543                                        Under World
# 5695963      5543                                        Under World
# 5695964      5621                     Violence Gekiga David no Hoshi
# 5695965      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
#
#                                         genre   type episodes  rating  \
# 0        Drama, Romance, School, Supernatural  Movie        1    9.37
# 1        Drama, Romance, School, Supernatural  Movie        1    9.37
# 2        Drama, Romance, School, Supernatural  Movie        1    9.37
# 3        Drama, Romance, School, Supernatural  Movie        1    9.37
# 4        Drama, Romance, School, Supernatural  Movie        1    9.37
# ...                                       ...    ...      ...     ...
# 5695961                                Hentai    OVA        1    4.15
# 5695962                                Hentai    OVA        1    4.28
# 5695963                                Hentai    OVA        1    4.28
# 5695964                                Hentai    OVA        4    4.88
# 5695965                                Hentai    OVA        1    4.98
#
#          members  user_id
# 0         200630       99
# 1         200630      152
# 2         200630      244
# 3         200630      271
# 4         200630      322
# ...          ...      ...
# 5695961      211    58483
# 5695962      183    49503
# 5695963      183    58483
# 5695964      219    49503
# 5695965      175    60365
#
# [5695966 rows x 8 columns]

# %% [markdown]
# **HERE I SWAPPED THE INDEX AND COLUMNS BECAUSE THE(1) NEEDS TO BE TRANSPOSED DUE TO SO MANY NAN**

# %% [markdown]
# **"IT IS SUGGESTED THAT TO USE KNN LOGIC INSTEAD OF COSINE SIM MATRIX IN THE GPT CHAT(then as mentioned the best approach is to use sparse matrix then what about cosine sim matrix problem) I'LL USE THE METHOD LATER"**

# %%
# user_item_matrix=dataset_AR.pivot_table(index="name",columns="user_id",values="rating")
# # user_item_matrix(1)=dataset_AR.pivot_table(index="user_id",columns="name",values="rating")
# user_item_matrix=user_item_matrix.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[21], line 3
#       1 user_item_matrix=dataset_AR.pivot_table(index="name",columns="user_id",values="rating")
#       2 # user_item_matrix(1)=dataset_AR.pivot_table(index="user_id",columns="name",values="rating")
# ----> 3 user_item_matrix=user_item_matrix.fillna(0)
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:7159, in NDFrame.fillna(self, value, axis, inplace, limit)
#    7155             if axis == 1:
#    7156                 result = self.T.fillna(value=value, limit=limit).T
#    7157                 new_data = result._mgr
#    7158             else:
# -> 7159                 new_data = self._mgr.fillna(value=value, limit=limit, inplace=inplace)
#    7160         elif isinstance(value, ABCDataFrame) and self.ndim == 2:
#    7161             new_data = self.where(self.notna(), value)._mgr
#    7162         else:
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:461, in BaseBlockManager.fillna(self, value, limit, inplace)
#     457 if limit is not None:
#     458     # Do this validation even if we go through one of the no-op paths
#     459     limit = libalgos.validate_limit(None, limit=limit)
# --> 461 return self.apply(
#     462     "fillna",
#     463     value=value,
#     464     limit=limit,
#     465     inplace=inplace,
#     466 )
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:1344, in Block.fillna(self, value, limit, inplace)
#    1342     nbs = self.putmask(mask.T, value)
#    1343 else:
# -> 1344     nbs = self.where(value, ~mask.T)
#    1345 return extend_blocks(nbs)
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:1305, in Block.where(self, other, cond)
#    1300             other = np.array(other).reshape(values.shape)
#    1301             # If lengths don't match (or len(other)==1), we will raise
#    1302             #  inside expressions.where, see test_series_where
#    1303
#    1304         # Note: expressions.where may upcast.
# -> 1305         result = expressions.where(~icond, values, other)
#    1306         # The np_can_hold_element check _should_ ensure that we always
#    1307         #  have result.dtype == self.dtype here.
#    1309 if transpose:
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:270, in where(cond, left_op, right_op, use_numexpr)
#     268 assert _where is not None
#     269 if use_numexpr:
# --> 270     return _where(cond, left_op, right_op)
#     271 else:
#     272     return _where_standard(cond, left_op, right_op)
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:184, in _where_standard(cond, left_op, right_op)
#     182 def _where_standard(cond, left_op, right_op):
#     183     # Caller is responsible for extracting ndarray if necessary
# --> 184     return np.where(cond, left_op, right_op)
#
# MemoryError: Unable to allocate 2.43 GiB for an array with shape (9875, 32967) and data type float64

# %%
# dataset_AR["rating"]=dataset_AR["rating"].astype("Float32")
# user_item_matrix=dataset_AR.pivot_table(index="name",columns="user_id",values="rating")
# sparse_matrix=csc_matrix(user_item_matrix.fillna(0).values)

# #DELETION OF USER_ITEM_MATRIX
# del user_item_matrix

# %%
# similarity_matrix2=cosine_similarity(user_item_matrix)
# similarity_matrix2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 similarity_matrix2=cosine_similarity(user_item_matrix)
#       2 similarity_matrix2
#
# NameError: name 'user_item_matrix' is not defined

# %% [markdown]
# **IT GOT CRASHED BECAUSE OF HUGE MEMORY(CAUSED OOM) SO DECIDED TO USE KNN APPROACH**

# %% [markdown]
# **-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
user_item_matrix=dataset_AR.pivot_table(index="name",columns="user_id",values="rating",fill_value=0).astype(np.float32)
sparse_matrix=csc_matrix(user_item_matrix.values)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 user_item_matrix=dataset_AR.pivot_table(index="name",columns="user_id",values="rating",fill_value=0).astype(np.float32)
#       2 sparse_matrix=csc_matrix(user_item_matrix.values)
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11159, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#   11155         **kwargs,
#   11156     ) -> DataFrame:
#   11157         from pandas.core.reshape.pivot import pivot_table
#   11158
# > 11159         return pivot_table(
#   11160             self,
#   11161             values=values,
#   11162             index=index,
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:267, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#     264     table = concat(pieces, keys=keys, axis=1)
#     265     return table.__finalize__(data, method="pivot_table")
# --> 267 table = __internal_pivot_table(
#     268     data,
#     269     values,
#     270     index,
#     271     columns,
#     272     aggfunc,
#     273     fill_value,
#     274     margins,
#     275     dropna,
#     276     margins_name,
#     277     observed,
#     278     sort,
#     279     kwargs,
#     280 )
#     281 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:364, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, kwargs)
#     362         else:
#     363             to_unstack.append(name)
# --> 364     table = agged.unstack(to_unstack, fill_value=fill_value)
#     366 if not dropna:
#     367     if isinstance(table.index, MultiIndex):
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11579, in DataFrame.unstack(self, level, fill_value, sort)
#   11575         dtype: float64
#   11576         """
#   11577         from pandas.core.reshape.reshape import unstack
#   11578
# > 11579         result = unstack(self, level, fill_value, sort)
#   11580
#   11581         return result.__finalize__(self, method="unstack")
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\reshape.py:583, in unstack(obj, level, fill_value, sort)
#     581 if isinstance(obj, DataFrame):
#     582     if isinstance(obj.index, MultiIndex):
# --> 583         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     584     else:
#     585         return obj.T.stack()
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\reshape.py:614, in _unstack_frame(obj, level, fill_value, sort)
#     612     return obj._constructor_from_mgr(mgr, axes=mgr.axes)
#     613 else:
# --> 614     return unstacker.get_result(
#     615         obj, value_columns=obj.columns, fill_value=fill_value
#     616     )
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\reshape.py:261, in _Unstacker.get_result(self, obj, value_columns, fill_value)
#     258 if value_columns is None and values.shape[1] != 1:  # pragma: no cover
#     259     raise ValueError("must pass column labels for multi-column data")
# --> 261 new_values, _ = self.get_new_values(values, fill_value)
#     262 columns = self.get_new_columns(value_columns)
#     263 index = self.new_index
#
# File c:\Users\Datta Sai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\reshape.py:337, in _Unstacker.get_new_values(self, values, fill_value)
#     329         elif not isna(fill_value):
#     330             warnings.warn(
#     331                 # GH#12189, GH#53868
#     332                 "Using a fill_value that cannot be held in the existing "
#    (...)    335                 stacklevel=find_stack_level(),
#     336             )
# --> 337 new_values = np.empty(result_shape, dtype=dtype)
#     338 if not mask_all:
#     339     new_values.fill(fill_value)
#
# MemoryError: Unable to allocate 2.43 GiB for an array with shape (9875, 32967) and data type float64

# %% [markdown]
# **NEED TO REDUCE MY DATASET**

# %%
datasetA.shape
# Out:
# (9875, 7)

# %%
datasetR.head()
# Out:
#    user_id  anime_id  rating
# 0        3        20       8
# 1        3       154       6
# 2        3       170       9
# 3        3       199      10
# 4        3       225       9

# %%
active_users = datasetR["user_id"].value_counts()

active_users = active_users[
    active_users > 200
].index

datasetR = datasetR[
    datasetR["user_id"].isin(active_users)
]

# %%
total_values=datasetR["user_id"].value_counts()
total_values
useful_values=total_values[total_values>=200].index
useful_values
# Out:
# Index([42635, 53698, 57620, 59643, 51693, 45659,  7345, 12431, 65840, 22434,
#        ...
#        68250, 70449, 70754, 70763, 71330, 71673, 71794, 71822, 72317, 72511],
#       dtype='int64', name='user_id', length=8713)

# %%
datasetR["user_id"].nunique()
# Out:
# 32967

# %%
datasetR=datasetR[datasetR["user_id"].isin(useful_values)]
datasetR["user_id"].value_counts()
# Out:
# user_id
# 42635    3747
# 53698    2905
# 57620    2689
# 59643    2632
# 51693    2620
#          ...
# 71673     200
# 71794     200
# 71822     200
# 72317     200
# 72511     200
# Name: count, Length: 8713, dtype: int64

# %%
datasetR.to_csv(r"D:\PRJ1\datasets\cleaneddatasets\newR.csv",index=False)

# %%
datasetA=datasetA[datasetA["anime_id"].isin(newR["anime_id"])]
datasetA.shape
# Out:
# (9786, 7)

# %%
newR['anime_id'].value_counts().count()
# Out:
# np.int64(9786)

# %%
newR["user_id"].value_counts().count()
# Out:
# np.int64(8713)

# %%
newR.shape
# Out:
# (3179694, 3)

# %%
datasetA.to_csv(r"D:\PRJ1\datasets\cleaneddatasets\newA.csv",index=False)

# %% [markdown]
# **KNN APPROACH:**

# %%
dataset_AR.shape
# Out:
# (5695966, 4)

# %%
ucodes=dataset_AR["user_id"].astype("category").cat.codes
acodes=dataset_AR["anime_id"].astype("category").cat.codes

# %%
rating_values=dataset_AR["rating"].astype(np.float32)

# %%
sparse_matrix=coo_matrix((rating_values,(acodes,ucodes)))

# %%
sparse_matrix=sparse_matrix.tocsr()

# %%
knn_model=NearestNeighbors(metric="cosine",algorithm="brute",n_neighbors=11)
knn_model.fit(sparse_matrix)
ani_to_index={anime:idx
              for idx, anime in enumerate(dataset_AR["name"].astype("category").cat.categories)}
index_to_ani={idx:anime
              for anime,idx in ani_to_index.items()}

# %%
def knn_recc_model(ani_name,no_recc=10):
    if ani_name not in ani_to_index:
        return "Anime not found!"
    ani_indx=ani_to_index[ani_name]
    distance,index=knn_model.kneighbors(sparse_matrix[ani_indx],n_neighbors=no_recc+1)
    recco=[]
    for i in range(1,len(distance.flatten())):
        recc_anime=index_to_ani[index.flatten()[i]]
        dist=distance.flatten()[i]
        recco.append(
            {"Anime":recc_anime,"Distance":dist}
        )
    return pd.DataFrame(recco)

# %%
knn_recc_model("Dream Hazard: Akuma no Program")
# Out:
#                                Anime  Distance
# 0      Higurashi no Naku Koro ni Kai  0.290011
# 1              Koukou Butouden Crows  0.467650
# 2                      &quot;0&quot;  0.507051
# 3  Colosseum no Senki: Another Story  0.510419
# 4                      Digital Juice  0.512132
# 5                    Docchi ni Suru?  0.513594
# 6    Getsumen To Heiki Mina Specials  0.528021
# 7                   Meisou-Ou Border  0.528513
# 8         Jungle Taitei: Susume Leo!  0.530377
# 9                            Believe  0.531583
