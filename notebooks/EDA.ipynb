# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"D:\PRJ1\datasets\archive\anime.csv")
data.groupby("type").count()
# Out:
#          anime_id  name  genre  episodes  rating  members
# type
# Movie        2348  2348   2306      2348    2297     2348
# Music         488   488    488       488     488      488
# ONA           659   659    655       659     652      659
# OVA          3311  3311   3310      3311    3285     3311
# Special      1676  1676   1674      1676    1671     1676
# TV           3787  3787   3777      3787    3671     3787

# %%
datasetR=pd.read_csv(r"D:\PRJ1\datasets\archive\rating.csv")
datasetR.head(20)
# Out:
#     user_id  anime_id  rating
# 0         1        20      -1
# 1         1        24      -1
# 2         1        79      -1
# 3         1       226      -1
# 4         1       241      -1
# 5         1       355      -1
# 6         1       356      -1
# 7         1       442      -1
# 8         1       487      -1
# 9         1       846      -1
# 10        1       936      -1
# 11        1      1546      -1
# 12        1      1692      -1
# 13        1      1836      -1
# 14        1      2001      -1
# 15        1      2025      -1
# 16        1      2144      -1
# 17        1      2787      -1
# 18        1      2993      -1
# 19        1      3455      -1

# %%
datasetA=pd.read_csv(r"D:\PRJ1\datasets\archive\anime.csv")
datasetA.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
datasetA.describe()
# Out:
#            anime_id       rating       members
# count   9875.000000  9875.000000  9.875000e+03
# mean   11402.152405     6.593161  2.193690e+04
# std    10457.018598     0.961845  5.991996e+04
# min        1.000000     2.000000  3.300000e+01
# 25%     2694.500000     6.060000  6.025000e+02
# 50%     7475.000000     6.670000  2.561000e+03
# 75%    18833.000000     7.260000  1.395950e+04
# max    34475.000000     9.370000  1.013917e+06

# %%
datasetA.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
datasetA=datasetA.dropna(subset=["genre","type"])

# %%
datasetA.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
datasetA.shape
# Out:
# (12210, 7)

# %%
datasetA["rating"]=datasetA["rating"].fillna(datasetA["rating"].median())

# %%
print(datasetA.to_string())
# Out:
#        anime_id                                                                                                  name                                                                                                                          genre     type episodes  rating  members
# 0         32281                                                                                        Kimi no Na wa.                                                                                           Drama, Romance, School, Supernatural    Movie        1    9.37   200630
# 1          5114                                                                      Fullmetal Alchemist: Brotherhood                                                                    Action, Adventure, Drama, Fantasy, Magic, Military, Shounen       TV       64    9.26   793665
# ...

# %%
datasetR.isnull().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
datasetR.shape,datasetA.shape
# Out:
# ((7813737, 3), (12210, 7))

# %%
(32281 in datasetA["anime_id"].values) and (32281 in datasetR["anime_id"].values)
# Out:
# True

# %%
datasetA[datasetA["anime_id"]==32281]
# Out:
#    anime_id            name                                 genre   type  \
# 0     32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
#
#   episodes  rating  members
# 0        1    9.37   200630

# %%
datasetR[datasetR["anime_id"]==32281]
# Out:
#          user_id  anime_id  rating
# 8271          99     32281       5
# 11961        152     32281      10
# 19665        244     32281      10
# 22985        271     32281      10
# 23382        278     32281      -1
# ...          ...       ...     ...
# 7758439    73042     32281       9
# 7763841    73099     32281      10
# 7764599    73109     32281       9
# 7791788    73311     32281       7
# 7792479    73319     32281       8
#
# [2199 rows x 3 columns]

# %%
11771 in datasetA["anime_id"]
# Out:
# True

# %%
datasetA[datasetA["anime_id"]==11771]
# Out:
#      anime_id              name                            genre type  \
# 122     11771  Kuroko no Basket  Comedy, School, Shounen, Sports   TV
#
#     episodes  rating  members
# 122       25    8.46   338315

# %%
datasetA.groupby(["type"]).count()
# Out:
#          anime_id  name  genre  episodes  rating  members
# type
# Movie        2306  2306   2306      2306    2306     2306
# Music         488   488    488       488     488      488
# ONA           655   655    655       655     655      655
# OVA          3310  3310   3310      3310    3310     3310
# Special      1674  1674   1674      1674    1674     1674
# TV           3777  3777   3777      3777    3777     3777

# %%
datasetR.groupby(["user_id"]).count()
# Out:
#          anime_id  rating
# user_id
# 1             153     153
# 2               3       3
# 3              94      94
# 4              52      52
# 5             467     467
# ...           ...     ...
# 73512          13      13
# 73513          33      33
# 73514           1       1
# 73515         196     196
# 73516           2       2
#
# [73515 rows x 2 columns]

# %%
datasetA[datasetA.duplicated()]
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
datasetR[datasetR.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [user_id, anime_id, rating]
# Index: []

# %%
datasetR[datasetR.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, anime_id, rating]
# Index: []

# %%
datasetR.loc[4499258]
# Out:
# user_id     42653
# anime_id    16498
# rating          8
# Name: 4499258, dtype: int64

# %%
datasetR=datasetR.drop_duplicates()

# %%
datasetR.loc[7813736]
# Out:
# user_id     73516
# anime_id     8074
# rating          9
# Name: 7813736, dtype: int64

# %%
datasetA.shape
# Out:
# (12210, 7)

# %%
datasetR.shape
# Out:
# (6337240, 3)

# %%
(datasetR["rating"]==-1).sum()
# Out:
# np.int64(0)

# %%
print(7813736-1476496)
# Out:
# 6337240

# %%
datasetR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6337240 entries, 47 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 193.4 MB

# %%
datasetA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9875 entries, 0 to 12292
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  9875 non-null   int64
#  1   name      9875 non-null   object
#  2   genre     9875 non-null   object
#  3   type      9875 non-null   object
#  4   episodes  9875 non-null   object
#  5   rating    9874 non-null   float64
#  6   members   9875 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 617.2+ KB

# %%
datasetR=datasetR[datasetR["rating"]!=-1]

# %%
datasetA["rating"]
# Out:
# 0        9.37
# 1        9.26
# 2        9.25
# 3        9.17
# 4        9.16
#          ...
# 12289    4.15
# 12290    4.28
# 12291    4.88
# 12292    4.98
# 12293    5.46
# Name: rating, Length: 12294, dtype: float64

# %%
s1=set(datasetA["anime_id"]) 
len(s1)
# Out:
# 9875

# %%
s2=set(datasetR["anime_id"])
len(s2)
# Out:
# 9875

# %%
s3=s1.intersection(s2)
len(s3)
# Out:
# 9875

# %%
haha=set(datasetA["anime_id"])-set(datasetR["anime_id"])
len(haha)
# Out:
# 0

# %%
len(s1)-len(s2)
# Out:
# 0

# %%
datasetA=datasetA[datasetA['anime_id'].isin(datasetR['anime_id'])]
datasetA.shape
# Out:
# (9875, 7)

# %%
datasetR=datasetR[datasetR["anime_id"].isin(datasetA['anime_id'])]

# %%
datasetR['anime_id'].value_counts()
# Out:
# anime_id
# 1535     34226
# 11757    26310
# 16498    25289
# 1575     24126
# 6547     23565
#          ...
# 23393        1
# 22221        1
# 26123        1
# 29837        1
# 8749         1
# Name: count, Length: 9926, dtype: int64

# %%
datasetR[datasetR["anime_id"]==8749]
# Out:
#          user_id  anime_id  rating
# 7776587    73188      8749       6

# %%
datasetR.head(20)
# Out:
#      user_id  anime_id  rating
# 47         1      8074      10
# 81         1     11617      10
# 83         1     11757      10
# 101        1     15451      10
# 153        2     11771      10
# 156        3        20       8
# 157        3       154       6
# 158        3       170       9
# 159        3       199      10
# 160        3       225       9
# 161        3       341       6
# 162        3       430       7
# 163        3       527       7
# 164        3       552       7
# 165        3       813      10
# 166        3      1119       7
# 167        3      1121       7
# 168        3      1122       7
# 169        3      1132       8
# 170        3      1292       6

# %%
total_users=datasetR['user_id'].value_counts()
# useful_users=total_users[total_users>=50]
total_users
# Out:
# user_id
# 42635    3747
# 53698    2905
# 57620    2689
# 59643    2632
# 51693    2620
#          ...
# 33607      50
# 31914      50
# 66821      50
# 67655      50
# 6386       50
# Name: count, Length: 32967, dtype: int64

# %%
useful_users=total_users[total_users>=50].index
len(useful_users)
# Out:
# 32967

# %%
datasetR=datasetR[datasetR['user_id'].isin(useful_users)]
len(datasetR)
# Out:
# 5695966

# %%
datasetR.nunique()
# Out:
# user_id     32967
# anime_id     9908
# rating         10
# dtype: int64

# %%
datasetA.nunique()
# Out:
# anime_id    9926
# name        9926
# genre       3048
# type           6
# episodes     178
# rating       574
# members     6474
# dtype: int64

# %%
datasetR[datasetR['anime_id']==21]
# Out:
# Empty DataFrame
# Columns: [user_id, anime_id, rating]
# Index: []

# %%
datasetA.loc[73]
# Out:
# anime_id                              5028
# name                              Major S5
# genre       Comedy, Drama, Romance, Sports
# type                                    TV
# episodes                                25
# rating                                8.58
# members                              28653
# Name: 73, dtype: object

# %%
datasetA["name"]=datasetA['name'].str.lower()
datasetA.head()
# Out:
#    anime_id                              name  \
# 0     32281                    kimi no na wa.
# 1      5114  fullmetal alchemist: brotherhood
# 2     28977                          gintama°
# 3      9253                       steins;gate
# 4      9969                     gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
datasetA.loc[73]
# Out:
# anime_id                              5028
# name                              major s5
# genre       Comedy, Drama, Romance, Sports
# type                                    TV
# episodes                                25
# rating                                8.58
# members                              28653
# Name: 73, dtype: object

# %%
datasetA.loc[74]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2606 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
datasetA=datasetA.reset_index(drop=True)
datasetR=datasetR.reset_index(drop=True)

# %%
datasetA.loc[74]
# Out:
# anime_id                                   17389
# name                          Kingdom 2nd Season
# genre       Action, Historical, Military, Seinen
# type                                          TV
# episodes                                      39
# rating                                      8.57
# members                                    31234
# Name: 74, dtype: object

# %%
datasetA.to_csv(r"D:\PRJ1\datasets\cleaneddatasets\Acleaned.csv",index=False)
datasetR.to_csv(r"D:\PRJ1\datasets\cleaneddatasets\Rcleaned.csv",index=False)
